# %%
import numpy as np
import os
import json
import pandas as pd

from pandas import Series, DataFrame

# %% [markdown]
# # Summary

# %% [markdown]
# - See the columns names
# - See index
# - See column with a specific name
# - Replace a value in the entire column
# - Subset dataframe with column names + non existing
# - Replace values in the Dataframe using a seies --> matching by index
# - From DICTIONARY TO PANDAS
#
# data.iloc[row selction, column_selection]
# - case-1    integer list [1,2,3]
# - case-2    slice of rows [4:7]
# - case-3    single value 1
#
# data.loc[row selction, column_selection]
# - case-4    index/label value , column name
# - case-5    list of labels    , list of clumn names
# - case-6    logic on the row values , slice of columns

# %% [markdown]
# # Development

# %%
ROOT = r'Q:\Delivery\GISdata\explorations\land_use_chris'
PATH_QML = os.path.join(ROOT, 'style','world_terr_ecosys.qml')
PATH_APRX = os.path.join(ROOT, 'style','world_terrestrial_ecosystems.lyrx')

# %%
file_aprx = open(PATH_APRX, mode='r')
file_text = file_aprx.read()
# print(type(file_text))
# print(file_text)
json_data = json.loads(file_text)
print(type(json_data))
# Out:
# <class 'dict'>

# %%
print(json_data)
# Out:
# {'type': 'CIMLayerDocument', 'version': '2.6.0', 'build': 24783, 'layers': ['CIMPATH=map/world_terr_ecosys_tif.xml'], 'layerDefinitions': [{'type': 'CIMRasterLayer', 'name': 'world_terr_ecosys.tif', 'uRI': 'CIMPATH=map/world_terr_ecosys_tif.xml', 'sourceModifiedTime': {'type': 'TimeInstant'}, 'useSourceMetadata': True, 'description': 'world_terr_ecosys.tif', 'layerElevation': {'type': 'CIMLayerElevationSurface', 'mapElevationID': '{68736750-D03D-4487-9309-E9680C569694}'}, 'expanded': True, 'layerType': 'Operational', 'showLegends': True, 'visibility': True, 'displayCacheType': 'Permanent', 'maxDisplayCacheAge': 5, 'showPopups': True, 'serviceLayerID': -1, 'refreshRate': -1, 'refreshRateUnit': 'esriTimeUnitsSeconds', 'dataConnection': {'type': 'CIMStandardDataConnection', 'workspaceConnectionString': 'DATABASE=.', 'workspaceFactory': 'Raster', 'dataset': 'world_terr_ecosys.tif', 'datasetType': 'esriDTRasterDataset'}, 'colorizer': {'type': 'CIMRasterUniqueValueColorizer', 'resamplingType': 'NearestNeighbor', 'noDataColor': {'type': 'CIMRGBColor', 'values': [255, 255, 255, 0]}, 'fieldName': 'ClassName', 'groups': [{'type': 'CIMRasterUniqueValueGroup', 'classes': [{'type': 'CIMRasterUniqueValueClass', 'values': ['Polar Moist Grassland on Mountains'], 'label': 'Polar Moist Grassland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [191, 167, 132, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Polar Moist Shrubland on Mountains'], 'label': 'Polar Moist Shrubland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [142, 67, 20, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Polar Moist Forest on Mountains'], 'label': 'Polar Moist Forest on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [107, 103, 74, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Polar Moist Settlement on Mountains'], 'label': 'Polar Moist Settlement on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [117, 102, 100, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Polar Moist Cropland on Mountains'], 'label': 'Polar Moist Cropland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [166, 133, 68, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Cool Temperate Moist Shrubland on Mountains'], 'label': 'Cool Temperate Moist Shrubland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [35, 83, 0, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Cool Temperate Moist Forest on Mountains'], 'label': 'Cool Temperate Moist Forest on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [6, 64, 0, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Cool Temperate Moist Cropland on Mountains'], 'label': 'Cool Temperate Moist Cropland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [33, 102, 5, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Cool Temperate Moist Grassland on Mountains'], 'label': 'Cool Temperate Moist Grassland on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [26, 83, 0, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Cool Temperate Moist Settlement on Mountains'], 'label': 'Cool Temperate Moist Settlement on Mountains', 'color': {'type': 'CIMRGBColor', 'values': [61, 67, 0, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Warm Temperate Moist Cropland on Plains'], 'label': 'Warm Temperate Moist Cropland on Plains', 'color': {'type': 'CIMRGBColor', 'values': [105, 207, 54, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Warm Temperate Moist Forest on Hills'], 'label': 'Warm Temperate Moist Forest on Hills', 'color': {'type': 'CIMRGBColor', 'values': [47, 146, 24, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Warm Temperate Moist Shrubland on Hills'], 'label': 'Warm Temperate Moist Shrubland on Hills', 'color': {'type': 'CIMRGBColor', 'values': [88, 172, 29, 100]}}, {'type': 'CIMRasterUniqueValueClass', 'values': ['Warm Temperate Moist Forest on Plains'], 'label': 'Warm Temperate Moist  ...

# %%
https://stackoverflow.com/questions/32311824/parsing-complex-json-with-python

# %%
print(file_text)
# Out:
# {
#   "type" : "CIMLayerDocument",
#   "version" : "2.6.0",
#   "build" : 24783,
#   "layers" : [
#     "CIMPATH=map/world_terr_ecosys_tif.xml"
#   ],
#   "layerDefinitions" : [
#     {
#       "type" : "CIMRasterLayer",
#       "name" : "world_terr_ecosys.tif",
#       "uRI" : "CIMPATH=map/world_terr_ecosys_tif.xml",
#       "sourceModifiedTime" : {
#         "type" : "TimeInstant"
#       },
#       "useSourceMetadata" : true,
#       "description" : "world_terr_ecosys.tif",
#       "layerElevation" : {
#         "type" : "CIMLayerElevationSurface",
#         "mapElevationID" : "{68736750-D03D-4487-9309-E9680C569694}"
#       },
#       "expanded" : true,
#       "layerType" : "Operational",
#       "showLegends" : true,
#       "visibility" : true,
#       "displayCacheType" : "Permanent",
#       "maxDisplayCacheAge" : 5,
#       "showPopups" : true,
#       "serviceLayerID" : -1,
#       "refreshRate" : -1,
#       "refreshRateUnit" : "esriTimeUnitsSeconds",
#       "dataConnection" : {
#         "type" : "CIMStandardDataConnection",
#         "workspaceConnectionString" : "DATABASE=.",
#         "workspaceFactory" : "Raster",
#         "dataset" : "world_terr_ecosys.tif",
#         "datasetType" : "esriDTRasterDataset"
#       },
#       "colorizer" : {
#         "type" : "CIMRasterUniqueValueColorizer",
#         "resamplingType" : "NearestNeighbor",
#         "noDataColor" : {
#           "type" : "CIMRGBColor",
#           "values" : [
#             255,
#             255,
#             255,
#             0
#           ]
#         },
#         "fieldName" : "ClassName",
#         "groups" : [
#           {
#             "type" : "CIMRasterUniqueValueGroup",
#             "classes" : [
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Polar Moist Grassland on Mountains"
#                 ],
#                 "label" : "Polar Moist Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     191,
#                     167,
#                     132,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Polar Moist Shrubland on Mountains"
#                 ],
#                 "label" : "Polar Moist Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     142,
#                     67,
#                     20,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Polar Moist Forest on Mountains"
#                 ],
#                 "label" : "Polar Moist Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     107,
#                     103,
#                     74,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Polar Moist Settlement on Mountains"
#                 ],
#                 "label" : "Polar Moist Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     117,
#                     102,
#                     100,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Polar Moist Cropland on Mountains"
#                 ],
#                 "label" : "Polar Moist Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     166,
#                     133,
#                     68,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Cool Temperate Moist Shrubland on Mountains"
#                 ],
#                 "label" : "Cool Temperate Moist Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     35,
#                     83,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Cool Temperate Moist Forest on Mountains"
#                 ],
#                 "label" : "Cool Temperate Moist Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     6,
#                     64,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Cool Temperate Moist Cropland on Mountains"
#                 ],
#                 "label" : "Cool Temperate Moist Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     33,
#                     102,
#                     5,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Cool Temperate Moist Grassland on Mountains"
#                 ],
#                 "label" : "Cool Temperate Moist Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     26,
#                     83,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Cool Temperate Moist Settlement on Mountains"
#                 ],
#                 "label" : "Cool Temperate Moist Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     61,
#                     67,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Cropland on Plains"
#                 ],
#                 "label" : "Warm Temperate Moist Cropland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     105,
#                     207,
#                     54,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Forest on Hills"
#                 ],
#                 "label" : "Warm Temperate Moist Forest on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     47,
#                     146,
#                     24,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Shrubland on Hills"
#                 ],
#                 "label" : "Warm Temperate Moist Shrubland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     88,
#                     172,
#                     29,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Forest on Plains"
#                 ],
#                 "label" : "Warm Temperate Moist Forest on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     45,
#                     158,
#                     6,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Shrubland on Plains"
#                 ],
#                 "label" : "Warm Temperate Moist Shrubland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     101,
#                     184,
#                     9,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Cropland on Hills"
#                 ],
#                 "label" : "Warm Temperate Moist Cropland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     112,
#                     198,
#                     86,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Grassland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     86,
#                     129,
#                     14,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Settlement on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     105,
#                     89,
#                     18,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Cropland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     100,
#                     150,
#                     37,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Sparsley or Non vegetated on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Sparsley or Non vegetated on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     126,
#                     149,
#                     37,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Shrubland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     102,
#                     130,
#                     4,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Forest on Mountains"
#                 ],
#                 "label" : "Warm Temperate Moist Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     49,
#                     105,
#                     3,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Settlement on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Moist Settlement on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     62,
#                     63,
#                     152,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Cropland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Moist Cropland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     61,
#                     89,
#                     194,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Grassland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Moist Grassland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     50,
#                     73,
#                     167,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Forest on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Moist Forest on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     69,
#                     72,
#                     136,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Moist Shrubland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Moist Shrubland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     105,
#                     97,
#                     199,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Shrubland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Dry Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     144,
#                     160,
#                     38,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Cropland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Dry Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     141,
#                     179,
#                     80,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Settlement on Mountains"
#                 ],
#                 "label" : "Warm Temperate Dry Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     144,
#                     124,
#                     59,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Grassland on Mountains"
#                 ],
#                 "label" : "Warm Temperate Dry Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     132,
#                     162,
#                     55,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Cropland on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Cropland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     155,
#                     228,
#                     99,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Settlement on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Settlement on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     189,
#                     190,
#                     72,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Grassland on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Grassland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     137,
#                     208,
#                     66,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Cropland on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Cropland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     153,
#                     217,
#                     128,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Settlement on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Settlement on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     173,
#                     187,
#                     99,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Grassland on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Grassland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     133,
#                     198,
#                     95,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Shrubland on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Shrubland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     136,
#                     198,
#                     73,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Forest on Mountains"
#                 ],
#                 "label" : "Warm Temperate Dry Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     96,
#                     139,
#                     37,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Forest on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Forest on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     94,
#                     186,
#                     42,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Shrubland on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Shrubland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     142,
#                     207,
#                     45,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Sparsley or Non vegetated on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Sparsley or Non vegetated on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     176,
#                     217,
#                     128,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Cropland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Dry Cropland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     95,
#                     117,
#                     206,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Forest on Hills"
#                 ],
#                 "label" : "Warm Temperate Dry Forest on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     91,
#                     175,
#                     66,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Settlement on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Dry Settlement on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     95,
#                     96,
#                     169,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Sparsley or Non vegetated on Plains"
#                 ],
#                 "label" : "Warm Temperate Dry Sparsley or Non vegetated on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     179,
#                     227,
#                     99,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Forest on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Dry Forest on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     100,
#                     103,
#                     156,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Shrubland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Dry Shrubland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     132,
#                     125,
#                     212,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Warm Temperate Dry Grassland on Tablelands"
#                 ],
#                 "label" : "Warm Temperate Dry Grassland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     82,
#                     103,
#                     184,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Shrubland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     150,
#                     88,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Forest on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     124,
#                     110,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Settlement on Hills"
#                 ],
#                 "label" : "Sub Tropical Moist Settlement on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     180,
#                     131,
#                     44,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Settlement on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     137,
#                     45,
#                     13,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Settlement on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Settlement on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     156,
#                     76,
#                     31,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Cropland on Hills"
#                 ],
#                 "label" : "Sub Tropical Moist Cropland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     189,
#                     228,
#                     77,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Forest on Hills"
#                 ],
#                 "label" : "Sub Tropical Moist Forest on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     125,
#                     178,
#                     16,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Cropland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     175,
#                     155,
#                     28,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Sparsley or Non vegetated on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Sparsley or Non vegetated on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     173,
#                     121,
#                     27,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Grassland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Moist Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     152,
#                     113,
#                     10,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Cropland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Cropland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     188,
#                     184,
#                     45,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Sparsley or Non vegetated on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Sparsley or Non vegetated on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     189,
#                     148,
#                     45,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Forest on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Forest on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     148,
#                     149,
#                     21,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Grassland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Grassland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     170,
#                     149,
#                     26,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Settlement on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Settlement on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     206,
#                     135,
#                     36,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Settlement on Hills"
#                 ],
#                 "label" : "Sub Tropical Dry Settlement on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     194,
#                     155,
#                     61,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Cropland on Hills"
#                 ],
#                 "label" : "Sub Tropical Dry Cropland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     182,
#                     234,
#                     86,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Grassland on Hills"
#                 ],
#                 "label" : "Sub Tropical Dry Grassland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     173,
#                     211,
#                     55,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Cropland on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Cropland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     203,
#                     246,
#                     54,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Sparsley or Non vegetated on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Sparsley or Non vegetated on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     245,
#                     237,
#                     53,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Shrubland on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Shrubland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     221,
#                     212,
#                     21,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Shrubland on Hills"
#                 ],
#                 "label" : "Sub Tropical Dry Shrubland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     194,
#                     211,
#                     37,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Shrubland on Mountains"
#                 ],
#                 "label" : "Sub Tropical Dry Shrubland on Mountains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     170,
#                     122,
#                     21,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Cropland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Cropland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     183,
#                     176,
#                     255,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Forest on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Forest on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     150,
#                     200,
#                     21,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Grassland on Plains"
#                 ],
#                 "label" : "Sub Tropical Dry Grassland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     203,
#                     224,
#                     30,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Forest on Hills"
#                 ],
#                 "label" : "Sub Tropical Dry Forest on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     129,
#                     191,
#                     33,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Sparsley or Non vegetated on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Sparsley or Non vegetated on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     146,
#                     157,
#                     212,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Shrubland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Shrubland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     124,
#                     133,
#                     233,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Forest on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Forest on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     103,
#                     109,
#                     171,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Grassland on Hills"
#                 ],
#                 "label" : "Sub Tropical Moist Grassland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     175,
#                     200,
#                     40,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Settlement on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Settlement on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     120,
#                     133,
#                     177,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Cropland on Plains"
#                 ],
#                 "label" : "Sub Tropical Moist Cropland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     217,
#                     243,
#                     41,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Dry Grassland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Dry Grassland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     198,
#                     204,
#                     249,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Sparsley or Non vegetated on Plains"
#                 ],
#                 "label" : "Sub Tropical Moist Sparsley or Non vegetated on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     240,
#                     212,
#                     41,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Shrubland on Plains"
#                 ],
#                 "label" : "Sub Tropical Moist Shrubland on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     212,
#                     180,
#                     1,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Forest on Plains"
#                 ],
#                 "label" : "Sub Tropical Moist Forest on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     153,
#                     189,
#                     0,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Cropland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Moist Cropland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     166,
#                     158,
#                     253,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Forest on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Moist Forest on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     73,
#                     78,
#                     152,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Grassland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Moist Grassland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     182,
#                     190,
#                     249,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Shrubland on Tablelands"
#                 ],
#                 "label" : "Sub Tropical Moist Shrubland on Tablelands",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     95,
#                     104,
#                     225,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Shrubland on Hills"
#                 ],
#                 "label" : "Sub Tropical Moist Shrubland on Hills",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     197,
#                     200,
#                     18,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
#                   "Sub Tropical Moist Settlement on Plains"
#                 ],
#                 "label" : "Sub Tropical Moist Settlement on Plains",
#                 "color" : {
#                   "type" : "CIMRGBColor",
#                   "values" : [
#                     195,
#                     102,
#                     18,
#                     100
#                   ]
#                 }
#               },
#               {
#                 "type" : "CIMRasterUniqueValueClass",
#                 "values" : [
# ...
#                 "values" : [
#                   94,
#                   97,
#                   176,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   182,
#                   179,
#                   16,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   182,
#                   179,
#                   16,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   116,
#                   44,
#                   3,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   116,
#                   44,
#                   3,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   105,
#                   112,
#                   0,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   105,
#                   112,
#                   0,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   130,
#                   150,
#                   36,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   130,
#                   150,
#                   36,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   100,
#                   77,
#                   7,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   100,
#                   77,
#                   7,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   58,
#                   43,
#                   0,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   58,
#                   43,
#                   0,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   255,
#                   116,
#                   1,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   255,
#                   116,
#                   1,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   139,
#                   204,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   139,
#                   204,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   255,
#                   190,
#                   18,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   255,
#                   190,
#                   18,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   81,
#                   105,
#                   2,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   81,
#                   105,
#                   2,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   80,
#                   48,
#                   0,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   80,
#                   48,
#                   0,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   127,
#                   14,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   127,
#                   14,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   78,
#                   32,
#                   0,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   78,
#                   32,
#                   0,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   66,
#                   10,
#                   0,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   66,
#                   10,
#                   0,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   105,
#                   65,
#                   16,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   105,
#                   65,
#                   16,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   111,
#                   3,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   120,
#                   111,
#                   3,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   91,
#                   113,
#                   192,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   91,
#                   113,
#                   192,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   128,
#                   88,
#                   191,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   128,
#                   88,
#                   191,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   68,
#                   59,
#                   111,
#                   100
#                 ]
#               }
#             },
#             {
#               "type" : "CIMLinearContinuousColorRamp",
#               "fromColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   68,
#                   59,
#                   111,
#                   100
#                 ]
#               },
#               "toColor" : {
#                 "type" : "CIMRGBColor",
#                 "values" : [
#                   64,
#                   66,
#                   159,
#                   100
#                 ]
#               }
#             }
#           ],
#           "weights" : [
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881,
#             0.0073529411764705881
#           ]
#         }
#       },
#       "attributeTable" : {
#         "type" : "CIMRasterTable",
#         "displayField" : "ClassName",
#         "editable" : true
#       }
#     }
#   ],
#   "elevationSurfaces" : [
#     {
#       "type" : "CIMMapElevationSurface",
#       "elevationMode" : "BaseGlobeSurface",
#       "name" : "Ground",
#       "verticalExaggeration" : 1,
#       "mapElevationID" : "{68736750-D03D-4487-9309-E9680C569694}",
#       "color" : {
#         "type" : "CIMRGBColor",
#         "values" : [
#           255,
#           255,
#           255,
#           100
#         ]
#       },
#       "surfaceTINShadingMode" : "Smooth",
#       "visibility" : true,
#       "expanded" : true
#     }
#   ],
#   "rGBColorProfile" : "sRGB IEC61966-2-1 noBPC",
#   "cMYKColorProfile" : "U.S. Web Coated (SWOP) v2"
# }

# %%
#Now we'll learn DataFrames

#Let's get some data to play with. How about the NFL?
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)

# %%
# This was the origna surce of data
# nfl_frame = pd.read_clipboard()
filepath = r'C:\Users\mp53\udemy-viz\textdata_in_mp003.csv'
nfl_frame = pd.read_csv(filepath, sep=',')

# %%
# Show the dataframe just imported
nfl_frame

# %%
# See the columns names
nfl_frame.columns

# %%
# See index
nfl_frame.index

# %%
# See column with a specific name
nfl_frame['Team']
print(nfl_frame)
# Replace a value in the entire column
nfl_frame['Division'] = 'Antony'

# %%
# Subset dataframe with column names + non existing
DataFrame(nfl_frame,columns=['Team','GP','Won','Luingi'])

# %%
# Replace values in the Dataframe using a seies --> matching by index
to_replace = Series(["replace1","replace2"],index=[1,3])
print(to_replace)

nfl_frame['Luingi'] = to_replace
nfl_frame

# %%
nfl_frame.head()
nfl_frame.tail()

# %%
## From DICTIONARY TO PANDAS
data = {'City': ['SF','LA','NYC'], 'Population':[8300000,3000000,10000000]}
data_df = DataFrame(data)
data_df
# Out:
#   City  Population
# 0   SF     8300000
# 1   LA     3000000
# 2  NYC    10000000

# %%
print('default')
print(data_df.to_dict())
print('list')
print(data_df.to_dict('list'))
print('series')
print(data_df.to_dict('series'))
print('split')
print(data_df.to_dict('split'))
print('records')
print(data_df.to_dict('records'))
print('index')
print(data_df.to_dict('index'))
# Out:
# default
# {'City': {0: 'SF', 1: 'LA', 2: 'NYC'}, 'Population': {0: 8300000, 1: 3000000, 2: 10000000}}
# list
# {'City': ['SF', 'LA', 'NYC'], 'Population': [8300000, 3000000, 10000000]}
# series
# {'City': 0     SF
# 1     LA
# 2    NYC
# Name: City, dtype: object, 'Population': 0     8300000
# 1     3000000
# 2    10000000
# Name: Population, dtype: int64}
# split
# {'index': [0, 1, 2], 'columns': ['City', 'Population'], 'data': [['SF', 8300000], ['LA', 3000000], ['NYC', 10000000]]}
# records
# [{'City': 'SF', 'Population': 8300000}, {'City': 'LA', 'Population': 3000000}, {'City': 'NYC', 'Population': 10000000}]
# index
# {0: {'City': 'SF', 'Population': 8300000}, 1: {'City': 'LA', 'Population': 3000000}, 2: {'City': 'NYC', 'Population': 10000000}}

# %%
nfl_frame.columns

# %% [markdown]
# # iloc , loc
#
# **iloc** Selecting data by row numbers (.iloc)
# **loc** Selecting data by label or by a conditional statment (.loc)
#
# data.iloc[row selction, column_selection]
# case-1    integer list [1,2,3]
# case-2    slice of rows [4:7]
# case-3    single value 1
#
# data.loc[row selction, column_selection]
# case-4    index/label value , column name
# case-5    list of labels    , list of clumn names
# case-6    logic on the row values , slice of columns

# %%
# iloc

# Case-1
case = nfl_frame.iloc[[0,1,2],[2,3,4]]
print(case)
# Case-2
# NB with this method the right-sode index must be one number higher
case = nfl_frame.iloc[0:3,2:5]
print(case)
# Case-3
case = nfl_frame.iloc[2,2]
print(case)

# %%
print(type(nfl_frame.iloc[1])) # Select one row
print(type(nfl_frame.iloc[[1]])) # Select one row as DATA FRAME
print(type(nfl_frame.iloc[0:2,])) # Select two rows
print(type(nfl_frame.iloc[:,1])) # Select one column
print(type(nfl_frame.iloc[:,[1]])) # Select one column as DATAFRAME 
print(type(nfl_frame.iloc[0:2,0:3])) # Select multiple row columns

# %%
# Case-4
case = nfl_frame.loc[:,['Division']] # as Dataframe
print(type(case))
case = nfl_frame.loc[:,'Division'] # as Series
print(type(case))
case = nfl_frame.loc[0,:] # as Series
print(case)

# Case-5
case = nfl_frame.loc[[0]]
print(type(case))
print(case)

case = nfl_frame.loc[0:3,['Division','Won']]
print(type(case))
print(case)

# Case-6
case = nfl_frame.loc[nfl_frame['Division']=='NFC North',['Won','Division']]
print(case)

# %% [markdown]
# # Exercise

# %%
import pandas as pd
import random
 
# read the data from the downloaded CSV file.
data = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  111
# 1     http://www.capgeminiamerica.co.uk  437
# 2      http://www.elliottjohnwesq.co.uk  940
# 3          http://www.mcmahanbenl.co.uk  944
# 4        http://www.champagneroom.co.uk  904

# %% [markdown]
# - See the columns names
# - See index
# - See column with a specific name
# - Replace a value in the entire column
# - Subset dataframe with column names + non existing
# - Replace values in the Dataframe using a series --> matching by index
# - From DICTIONARY TO PANDAS
# - From PANDAS to DICTIONARIY (empty, list, series, split, records, index)
#
# data.iloc[row selction, column_selection]
# - case-1    integer list [1,2,3]
# - case-2    slice of rows [4:7]
# - case-3    single value 1
#
# data.loc[row selction, column_selection]
# - case-4    index/label value , column name
# - case-5    list of labels    , list of clumn names
# - case-6    logic on the row values , slice of columns

# %%
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web', 'id', 'email2', 'santo'],
#       dtype='object')
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# 2          8 Moor Place  East Southbourne and Tuckton W      Bournemouth
# 3         505 Exeter Rd              Hawerby cum Beesby     Lincolnshire
# 4     5396 Forth Street      Greets Green and Lyng Ward    West Midlands
# ..                  ...                             ...              ...
# 495  9166 Devon St #905  Knightsbridge and Belgravia Wa   Greater London
# 496        70 Foster St        Inverness Ness-Side Ward         Highland
# 497     714 Fonthill Rd                Darton West Ward  South Yorkshire
# 498         9 Milton St                Consett North ED    County Durham
# 499     6 Norwood Grove               Tanworth-in-Arden     Warwickshire
#
#        postal        phone1        phone2                       email  \
# 0     CT2 7PP  01835-703597  01944-369967     atomkiewicz@hotmail.com
# 1    HP11 2AX  01937-864715  01714-737668    evan.zigomalas@gmail.com
# 2     BH6 3BE  01347-368222  01935-821636  france.andrade@hotmail.com
# 3    DN36 5RP  01912-771311  01302-601380         ulysses@hotmail.com
# 4     B70 9DT  01547-429341  01290-367248   tyisha.veness@hotmail.com
# ..        ...           ...           ...                         ...
# 495  SW1W 8JY  01748-625058  01369-185737            avery@veit.co.uk
# 496   IV2 6WT  01916-963261  01370-319414      reuresti@euresti.co.uk
# 497   S75 5EJ  01888-152110  01301-312487    cbrenning@brenning.co.uk
# 498   DH8 5LP  01877-379681  01600-463475   celestina_keeny@gmail.com
# 499   B94 5RZ  01451-785624  01202-738406              mi@hotmail.com
#
#                                              web   id  email2    santo
# 0           http://www.alandrosenburgcpapc.co.uk  111  luiggi  johnson
# 1              http://www.capgeminiamerica.co.uk  437  luiggi     jane
# 2               http://www.elliottjohnwesq.co.uk  940  luiggi     July
# 3                   http://www.mcmahanbenl.co.uk  944  luiggi      NaN
# 4                 http://www.champagneroom.co.uk  904  luiggi      NaN
# ..                                           ...  ...     ...      ...
# 495    http://www.plazagourmetdelicatessen.co.uk  491  luiggi      NaN
# 496           http://www.fitzgeraldedwardj.co.uk  882  luiggi      NaN
# 497             http://www.fureyassociates.co.uk  314  luiggi      NaN
# 498       http://www.bfgfederalcreditunion.co.uk  858  luiggi      NaN
# 499  http://www.nelsonwrighthaworthgolfcrs.co.uk  843  luiggi      NaN
#
# [500 rows x 14 columns]

# %%
# data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
# data.iloc[1] # second row of data frame (Evan Zigomalas)
# data.iloc[-1] # last row of data frame (Mi Richan)
# # Columns:
data.iloc[:,0] # first column of data frame (first_name)
# data.iloc[:,1] # second column of data frame (last_name)
# data.iloc[:,-1] # last column of data frame (id)

# %%
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5] # first five rows of dataframe
data.iloc[:, 0:2] # first two columns of data frame with all rows
data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
